# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %%
def simple_get(url):
    
    try:
        with closing(get(url)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    
    print(e)

# %%
ab=simple_get('https://www.pdfdrive.com/')

# %%
len(ab)
# Out:
# 59022

# %%
raw_html = simple_get('https://www.pdfdrive.com/')
html = BeautifulSoup(raw_html, 'html.parser')
for i, li in enumerate(html.select('li')):
    print(i, li.text)
# Out:
# 0 Home
# 1 Most Popular
# 2 Editor's Picks
# 3 Explore
# 4 Contact
# 5
#
#
#
#
#
#
#
#
#
#
# Living in the Light: A guide to personal transformation
#
#
# 258 Pages·2001·2.74 MB·178,012 Downloads
# 6
#
#
#
#
#
#
#
#
#
#
# Give and Take: WHY HELPING OTHERS DRIVES OUR SUCCESS
#
#
# 260 Pages·2011·1.57 MB·257,030 Downloads
# 7
#
#
#
#
#
#
#
#
#
#
# Mindset: The New Psychology of Success
#
#
# 147 Pages·2010·1.06 MB·330,458 Downloads
# 8
#
#
#
#
#
#
#
#
#
#
# Braiding Sweetgrass: Indigenous Wisdom, Scientific Knowledge and the Teachings of Plants
#
#
# 473 Pages·2017·2.03 MB·83,478 Downloads
# 9
#
#
#
#
#
#
#
#
#
#
# The Power of Now: A Guide to Spiritual Enlightenment
#
#
# 2004·1023 KB·155,628 Downloads
# 10
#
#
# (adsbygoogle=window.adsbygoogle||[]).push({});
#
# 11
#
#
#
#
#
#
#
#
#
#
# I am Malala: The Story of the Girl Who Stood Up for Education
#
#
# 195 Pages·2012·3.04 MB·190,454 Downloads
# 12
#
#
#
#
#
#
#
#
#
#
# Resisting Happiness: A True Story about Why We Sabotage Ourselves
#
#
# 32 Pages·2017·258 KB·113,299 Downloads
# 13
#
#
#
#
#
#
#
#
#
#
# Start Where You Are: A Guide to Compassionate Living
#
#
# 242 Pages·2007·1022 KB·136,464 Downloads
# 14
#
#
#
#
#
#
#
#
#
#
# The Purpose-Driven Life: What on Earth Am I Here For?
#
#
# 2003·3.65 MB·126,485 Downloads
# 15
#
#
# (adsbygoogle=window.adsbygoogle||[]).push({});
#
# 16
#
#
#
#
#
#
#
#
#
#
# The Conscious Parent: Transforming Ourselves, Empowering Our Children
#
#
# 334 Pages·2017·1.55 MB·103,295 Downloads
# 17
#
#
#
#
#
#
#
#
#
#
# Parenting With Love and Logic: Teaching Children Responsibility
#
#
# 305 Pages·2017·1.81 MB·94,002 Downloads
# 18
#
#
#
#
#
#
#
#
#
#
# No-Drama Discipline: The Whole-Brain Way to Calm the Chaos and Nurture Your Child's Developing Mind
#
#
# 345 Pages·2017·13.27 MB·99,011 Downloads
# 19
#
#
#
#
#
#
#
#
#
#
# 1-2-3 Magic: 3-Step Discipline for Calm, Effective, and Happy Parenting
#
#
# 322 Pages·2017·6.23 MB·95,095 Downloads
# 20
#
#
#
#
#
#
#
#
#
#
# The Explosive Child: A New Approach for Understanding and Parenting Easily Frustrated, Chronically I
#
#
# 318 Pages·2010·714 KB·32,807 Downloads
# 21
#
#
# (adsbygoogle=window.adsbygoogle||[]).push({});
#
# 22
#
#
#
#
#
#
#
#
#
#
# The Gifts of Imperfection: Embrace Who You Are
#
#
# 98 Pages·2015·1.1 MB·183,924 Downloads
# 23
#
#
#
#
#
#
#
#
#
#
# The Book of Joy: Lasting Happiness in a Changing World by Dalai Lama
#
#
# 283 Pages·2017·5.37 MB·123,565 Downloads
# 24
#
#
#
#
#
#
#
#
#
#
# The Choice: Embrace the Possible
#
#
# 359 Pages·2017·1.99 MB·63,857 Downloads
# 25
#
#
#
#
#
#
#
#
#
#
# Boundaries: When to Say Yes, How to Say No to Take Control of Your Life
#
#
# 357 Pages·2001·1.9 MB·252,256 Downloads
# 26
#
#
#
#
#
#
#
#
#
#
# The Seven Principles for Making Marriage Work
#
#
# 277 Pages·2009·1.39 MB·135,327 Downloads
# 27
#
#
#
#
#
#
#
#
#
#
# The 5 Second Rule: Transform your Life, Work, and Confidence with Everyday Courage
#
#
# 252 Pages·2017·11.94 MB·393,262 Downloads
# 28
#
#
#
#
#
#
#
#
#
#
# The Daily Stoic: 366 Meditations on Wisdom, Perseverance, and the Art of Living
#
#
# 406 Pages·2017·2.6 MB·168,247 Downloads
# 29
#
#
# Listen to this before you start your day!
#
# 30
#
#
# Anxiety - Short Film
#
# 31
#
#
# Steve Jobs' 2005 Stanford Commencement Address
#
# 32
#
#
# The War on Consciousness - Graham Hancock
#
# 33
#
#
# If We Love | Short Film
#
# 34
#
#
# Jim Carrey - What It All Means
#
# 35
#
#
# Money, happiness and eternal life - Greed
#
# 36
#
#
# The One Thing Only 1% of People Do
#
# 37
#
#
# Practice This For a Few MINUTES Each day
#
# 38
#
#
# Why I read a book a day (and why you should too)
#
# 39
#
#
# This company tested out a 4-day workweek.
#
# 40
#
#
# Best Friend - Animation Short Film
#
# 41
#
#
# Editor's Picks
#
#
# 42
#
#
# Most Popular
#
#
# 43
#
#
# Academic & Education
#
#
# 44
#
#
# Art
#
#
# 45
#
#
# Biography
#
#
# 46
#
#
# Business & Career
#
#
# 47
#
#
# Children & Youth
#
#
# 48
#
#
# Environment
#
#
# 49
#
#
# Fiction & Literature
#
#
# 50
#
#
# Health & Fitness
#
#
# 51
#
#
# Lifestyle
#
#
# 52
#
#
# Personal Growth
#
#
# 53
#
#
# Politics & Laws
#
#
# 54
#
#
# Religion
#
#
# 55
#
#
# Science & Research
#
#
# 56
#
#
# Technology

# %%
def get_book_names():
    
    response = simple_get('https://www.pdfdrive.com/')

    if response is not None:
        html = BeautifulSoup(response, 'html.parser')
        names = set()
        for li in html.select('li'):
            for name in li.text.split('\n'):
                if len(name) > 0:
                    names.add(name.strip())
        return list(names)

    # Raise an exception if we failed to get any data from the url
    raise Exception('Error retrieving contents at {}'.format(url))

# %%
get_book_names()
# Out:
# ['',
#  'Best Friend - Animation Short Film',
#  'Start Where You Are: A Guide to Compassionate Living',
#  'The Seven Principles for Making Marriage Work',
#  'Politics & Laws',
#  '359 Pages·2017·1.99 MB·63,857 Downloads',
#  "No-Drama Discipline: The Whole-Brain Way to Calm the Chaos and Nurture Your Child's Developing Mind",
#  'Health & Fitness',
#  'Art',
#  'This company tested out a 4-day workweek.',
#  'Resisting Happiness: A True Story about Why We Sabotage Ourselves',
#  'Lifestyle',
#  'Mindset: The New Psychology of Success',
#  'Braiding Sweetgrass: Indigenous Wisdom, Scientific Knowledge and the Teachings of Plants',
#  'Practice This For a Few MINUTES Each day',
#  'Religion',
#  'Home',
#  'Parenting With Love and Logic: Teaching Children Responsibility',
#  '260 Pages·2011·1.57 MB·257,030 Downloads',
#  'The Daily Stoic: 366 Meditations on Wisdom, Perseverance, and the Art of Living',
#  'I am Malala: The Story of the Girl Who Stood Up for Education',
#  'Give and Take: WHY HELPING OTHERS DRIVES OUR SUCCESS',
#  '473 Pages·2017·2.03 MB·83,478 Downloads',
#  'Business & Career',
#  'Money, happiness and eternal life - Greed',
#  '(adsbygoogle=window.adsbygoogle||[]).push({});',
#  'Living in the Light: A guide to personal transformation',
#  "Steve Jobs' 2005 Stanford Commencement Address",
#  'Why I read a book a day (and why you should too)',
#  'Academic & Education',
#  'If We Love | Short Film',
#  '318 Pages·2010·714 KB·32,807 Downloads',
#  'Biography',
#  'Most Popular',
#  'Science & Research',
#  'The War on Consciousness - Graham Hancock',
#  "Editor's Picks",
#  'The Conscious Parent: Transforming Ourselves, Empowering Our Children',
#  'The Explosive Child: A New Approach for Understanding and Parenting Easily Frustrated, Chronically I',
#  'Fiction & Literature',
#  '242 Pages·2007·1022 KB·136,464 Downloads',
#  '2004·1023 KB·155,628 Downloads',
#  'Environment',
#  'The 5 Second Rule: Transform your Life, Work, and Confidence with Everyday Courage',
#  '32 Pages·2017·258 KB·113,299 Downloads',
#  '345 Pages·2017·13.27 MB·99,011 Downloads',
#  'Technology',
#  '2003·3.65 MB·126,485 Downloads',
#  '147 Pages·2010·1.06 MB·330,458 Downloads',
#  'The One Thing Only 1% of People Do',
#  'The Gifts of Imperfection: Embrace Who You Are',
#  '305 Pages·2017·1.81 MB·94,002 Downloads',
#  '406 Pages·2017·2.6 MB·168,247 Downloads',
#  'Personal Growth',
#  '252 Pages·2017·11.94 MB·393,262 Downloads',
#  '322 Pages·2017·6.23 MB·95,095 Downloads',
#  'Boundaries: When to Say Yes, How to Say No to Take Control of Your Life',
#  'The Choice: Embrace the Possible',
#  '195 Pages·2012·3.04 MB·190,454 Downloads',
#  'The Book of Joy: Lasting Happiness in a Changing World by Dalai Lama',
#  '98 Pages·2015·1.1 MB·183,924 Downloads',
#  'Anxiety - Short Film',
#  'Children & Youth',
#  'Jim Carrey - What It All Means',
#  '1-2-3 Magic: 3-Step Discipline for Calm, Effective, and Happy Parenting',
#  '334 Pages·2017·1.55 MB·103,295 Downloads',
#  'Contact',
#  'Explore',
#  'The Purpose-Driven Life: What on Earth Am I Here For?',
#  'The Power of Now: A Guide to Spiritual Enlightenment',
#  '283 Pages·2017·5.37 MB·123,565 Downloads',
#  'Listen to this before you start your day!',
#  '258 Pages·2001·2.74 MB·178,012 Downloads',
#  '277 Pages·2009·1.39 MB·135,327 Downloads',
#  '357 Pages·2001·1.9 MB·252,256 Downloads']
